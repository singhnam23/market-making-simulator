# %%
import sys
sys.path.append('..')

from data_parsers import databento_file_parser
from executor import SimpleExecutor1

import pandas as pd
import math
import numpy as np

from tqdm import tqdm
import math
import numpy
import matplotlib.pyplot as plt
import random
import numpy as np

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 80)

# %%
# Marco Avellaneda & Sasha Stoikov

''' 
This algo give bid and ask quote based on the Sasha Stoikov and Marco Avellaneda Model

Input:
- mid_price = current mid price
- sigma = market volatility    
- q = current position    
- qmax = maximum position
- gamma = 0.1, risk aversion parameter
- k = 1.5, Market model parameter
'''

def quote_ho_and_stoll(mid_price, q, a = 0.01, b=0.01):

    s = 0.06

    sign = -1 if q > 0 else +1
    abs_q = np.abs(q)

    d = sign * (a * abs_q + b * abs_q ** 2) / 100
    
    ra = mid_price + s / 2 + d / 2
    rb = mid_price - s / 2 + d / 2
    
    ra = ra.round(2)
    rb = rb.round(2)
        
    return rb, ra

quote_ho_and_stoll(10, -200, a = 0.01, b=0.0001)
# Out:
# (10.0, 10.06)

# %%
class BOT1(SimpleExecutor1):

    def calculate_bid_ask_price(self, bid_orderbook, ask_orderbook, inventory):
        """
        Compute the bid and ask prices based on orderbook status and inventory
        Needs to be overwritten by the model
        """
        mid_price = (ask_orderbook[0][0] + bid_orderbook[0][0])/2
        bid, ask = quote_ho_and_stoll(mid_price, inventory, a = 0.01, b=0.0001)
        if self.is_verbose_cnt():
            print(f"{mid_price=} {bid=} {ask=} {self.sigma_1min=:.4f} {self.time_frac_elapsed=:.4f}")

        return bid, ask

# %%
from itertools import product

# TICKERS = ['AMZN', 'MSFT', 'APPL']
# TRAIN_DATES = ['20230515', '20230516']
# TEST_DATES = ['20230517', '20230518', '20230519']

TICKERS = ['MSFT']
TEST_DATES = ['20230515', '20230516', '20230517', '20230518', '20230519']
# TEST_DATES = ['20230519']


# TRAIN_SAMPLE = list(product(TICKERS, TRAIN_DATES))
# TRAIN_SAMPLE

TEST_SAMPLE = list(product(TICKERS, TEST_DATES))
TEST_SAMPLE
# Out:
# [('MSFT', '20230515'),
#  ('MSFT', '20230516'),
#  ('MSFT', '20230517'),
#  ('MSFT', '20230518'),
#  ('MSFT', '20230519')]

# %%
output = {}
for ticker, date in TEST_SAMPLE:
    data_file_path = f'../data/databento/{ticker}/xnas-itch-{date}.mbp-10.dbn.zst'
    data_df = databento_file_parser(data_file_path)
    print(f"*** Starting for {ticker=} and {date=} ***")
    print(len(data_df))
    for start_ts, group_df in data_df.resample('30min'):
        print(start_ts, len(group_df))
        bot1 = BOT1(ticker=ticker, print_freq=150_000)
        bot1.run_sim(group_df)
        output[(ticker, start_ts)] = bot1.output_data
        # print(output[(ticker, start_ts)])
# Out:
# *** Starting for ticker='MSFT' and date='20230515' ***
# 1248264
# 2023-05-15 14:00:00 148372
# mid_price=308.81 bid=308.78 ask=308.84 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-7104.419999999984 position=23 pnl=-5.5699999999842476 trading_pnl=45.645000000002824 trading_volume=2175 avg_size=5.18944351622846 avg_size_square=58.4937718706461
# 2023-05-15 14:30:00 143007
# mid_price=307.665 bid=307.64 ask=307.7 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-22878.200000000004 position=74 pnl=22.999999999995342 trading_pnl=52.45000000000721 trading_volume=2188 avg_size=6.8825384509142316 avg_size_square=138.39785890346457
# 2023-05-15 15:00:00 110186
# mid_price=309.185 bid=309.16 ask=309.21 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-1221.1999999999825 position=4 pnl=36.880000000017446 trading_pnl=36.83000000000578 trading_volume=1956 avg_size=7.402431479188921 avg_size_square=173.25254392232355
# 2023-05-15 15:30:00 96071
# mid_price=309.57 bid=309.54 ask=309.6 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-3982.159999999996 position=13 pnl=57.720000000003786 trading_pnl=34.24499999999973 trading_volume=1313 avg_size=5.496458488388166 avg_size_square=72.98062858809502
# 2023-05-15 16:00:00 86253
# mid_price=309.755 bid=309.73 ask=309.78 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-2431.279999999988 position=8 pnl=54.860000000012114 trading_pnl=37.62500000000107 trading_volume=1318 avg_size=6.16264068634892 avg_size_square=86.92101392153438
# 2023-05-15 16:30:00 82238
# mid_price=309.12 bid=309.09 ask=309.15 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=15750.130000000012 position=-51 pnl=-0.8199999999880667 trading_pnl=14.5849999999994 trading_volume=805 avg_size=8.70984007539458 avg_size_square=147.09428565306555
# 2023-05-15 17:00:00 91849
# mid_price=308.96500000000003 bid=308.94 ask=309.0 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-36793.67999999999 position=119 pnl=-2.229999999995634 trading_pnl=61.150000000000325 trading_volume=1807 avg_size=4.911470978081047 avg_size_square=62.87363230695084
# 2023-05-15 17:30:00 101879
# mid_price=309.02 bid=308.99 ask=309.05 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=8325.13000000001 position=-27 pnl=-4.049999999991414 trading_pnl=21.465000000003457 trading_volume=1139 avg_size=6.554784534365143 avg_size_square=142.0698343517863
# 2023-05-15 18:00:00 86955
# mid_price=308.945 bid=308.92 ask=308.97 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-7699.699999999986 position=25 pnl=34.580000000013825 trading_pnl=25.620000000002193 trading_volume=1103 avg_size=8.380576720201558 avg_size_square=163.69841912729143
# 2023-05-15 18:30:00 88353
# mid_price=308.96500000000003 bid=308.94 ask=309.0 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-1236.6299999999883 position=4 pnl=8.510000000011678 trading_pnl=16.975000000005743 trading_volume=910 avg_size=5.791873357401581 avg_size_square=90.515975119612
# 2023-05-15 19:00:00 86851
# mid_price=308.975 bid=308.95 ask=309.0 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=2472.3400000000047 position=-8 pnl=4.420000000004566 trading_pnl=11.529999999998328 trading_volume=744 avg_size=10.68818544050564 avg_size_square=211.3734793644553
# 2023-05-15 19:30:00 126250
# mid_price=309.395 bid=309.36 ask=309.42 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=27840.330000000016 position=-90 pnl=21.99000000001557 trading_pnl=72.40500000000166 trading_volume=3486 avg_size=9.869227799494984 avg_size_square=206.96715652995567
# *** Starting for ticker='MSFT' and date='20230516' ***
# 1391177
# 2023-05-16 14:00:00 173706
# mid_price=312.15 bid=312.12 ask=312.18 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# self.current_ts=Timestamp('2023-05-16 14:25:40.593610314')
# self.BID_SIM_ORDER_BOOK={0: (312.42, 8), 1: (312.41, 105), 2: (312.4, 208), 3: (312.39, 86), 4: (312.38, 60), 5: (312.37, 110), 6: (312.36, 210), 7: (312.35, 260), 8: (312.34, 100), 9: (312.33, 150)}
# self.ASK_SIM_ORDER_BOOK={0: (312.44, 208), 1: (312.45, 244), 2: (312.46, 368), 3: (312.47, 218), 4: (312.48, 268), 5: (312.49, 168), 6: (312.5, 184), 7: (312.51, 160), 8: (312.52, 94), 9: (312.53, 212)}
# self.BID_ALGO_ORDERS={312.4: 9}
# self.ASK_ALGO_ORDERS={312.45: 26}
# self.ALGO_POSITION=6
#
# mid_price=312.43 bid=312.4 ask=312.46 self.sigma_1min=0.0544 self.time_frac_elapsed=0.8559
# capital=-1231.769999999984 position=4 pnl=59.25000000001589 trading_pnl=101.68000000001868 trading_volume=4222 avg_size=6.322775463217847 avg_size_square=133.69274491431472
# 2023-05-16 14:30:00 139763
# mid_price=312.26 bid=312.23 ask=312.29 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-9067.979999999978 position=29 pnl=21.260000000022046 trading_pnl=44.360000000008256 trading_volume=1775 avg_size=5.677647614141757 avg_size_square=81.95083863660088
# 2023-05-16 15:00:00 128630
# mid_price=312.78999999999996 bid=312.76 ask=312.82 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-10043.299999999985 position=32 pnl=5.800000000016009 trading_pnl=44.6450000000049 trading_volume=2190 avg_size=5.142460308237693 avg_size_square=64.83789309632625
# 2023-05-16 15:30:00 115229
# mid_price=313.46000000000004 bid=313.43 ask=313.49 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-9130.849999999973 position=29 pnl=-15.269999999972786 trading_pnl=36.10000000000818 trading_volume=1915 avg_size=8.880029279131248 avg_size_square=200.76516010389878
# 2023-05-16 16:00:00 98298
# mid_price=313.545 bid=313.52 ask=313.58 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-943.1099999999951 position=3 pnl=4.230000000004861 trading_pnl=13.194999999998867 trading_volume=795 avg_size=7.08039964780584 avg_size_square=105.64925102096603
# 2023-05-16 16:30:00 100813
# mid_price=313.15 bid=313.12 ask=313.18 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-17854.549999999977 position=57 pnl=-6.209999999975551 trading_pnl=45.06500000000317 trading_volume=1817 avg_size=7.884614467994471 avg_size_square=265.10276752714356
# 2023-05-16 17:00:00 91552
# mid_price=312.945 bid=312.92 ask=312.97 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-931.1800000000003 position=3 pnl=17.97999999999971 trading_pnl=19.404999999998697 trading_volume=1091 avg_size=7.264405044241059 avg_size_square=97.33240730416081
# 2023-05-16 17:30:00 86843
# mid_price=312.77 bid=312.74 ask=312.8 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=13793.01000000001 position=-44 pnl=19.570000000008005 trading_pnl=16.655000000002413 trading_volume=912 avg_size=10.822053031120682 avg_size_square=256.7366395668014
# 2023-05-16 18:00:00 102213
# mid_price=313.375 bid=313.35 ask=313.4 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-4694.509999999977 position=15 pnl=11.110000000023065 trading_pnl=29.630000000010938 trading_volume=1347 avg_size=5.612860335626184 avg_size_square=66.65321480172379
# 2023-05-16 18:30:00 102459
# mid_price=312.83 bid=312.8 ask=312.86 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-5639.789999999979 position=18 pnl=5.990000000020665 trading_pnl=27.279999999999085 trading_volume=1646 avg_size=12.688469906178431 avg_size_square=345.2219343996811
# 2023-05-16 19:00:00 107087
# mid_price=312.74 bid=312.71 ask=312.77 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=23181.530000000013 position=-74 pnl=13.690000000014408 trading_pnl=48.35500000001073 trading_volume=2228 avg_size=6.768138923852268 avg_size_square=134.49766625537987
# 2023-05-16 19:30:00 144584
# mid_price=313.315 bid=313.29 ask=313.34 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-1891.569999999956 position=6 pnl=25.010000000043895 trading_pnl=104.96000000001507 trading_volume=4602 avg_size=6.2723419779566 avg_size_square=106.01978818810932
# *** Starting for ticker='MSFT' and date='20230517' ***
# 1311611
# 2023-05-17 14:00:00 126288
# mid_price=311.72 bid=311.69 ask=311.75 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-2839.6599999999853 position=9 pnl=-11.119999999985303 trading_pnl=66.95000000000383 trading_volume=2729 avg_size=6.368936360172652 avg_size_square=105.3056676475723
# 2023-05-17 14:30:00 100893
# mid_price=311.225 bid=311.2 ask=311.26 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-2485.3899999999844 position=8 pnl=21.930000000015518 trading_pnl=24.16500000000331 trading_volume=1324 avg_size=6.399009173815716 avg_size_square=103.81636844290152
# 2023-05-17 15:00:00 133438
# mid_price=311.8 bid=311.77 ask=311.83 self.sigma_1min=0.1000 self.time_frac_elapsed=0.0000
# capital=-12842.699999999968 position=41 pnl=-43.10999999996798 trading_pnl=87.63000000000758 trading_volume=2809 avg_size=6.873977247709722 avg_size_square=134.88542754330533
# 2023-05-17 15:30:00 100558
# mid_price=311.515 bid=311.48 ask=311.54 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=8753.330000000002 position=-28 pnl=24.190000000001604 trading_pnl=40.545000000002645 trading_volume=1470 avg_size=5.971124391651149 avg_size_square=102.91408285114048
# 2023-05-17 16:00:00 77560
# mid_price=312.305 bid=312.28 ask=312.33 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-6567.709999999995 position=21 pnl=1.1600000000060398 trading_pnl=15.50500000000078 trading_volume=805 avg_size=5.433660034346589 avg_size_square=73.09932653614779
# 2023-05-17 16:30:00 109167
# mid_price=312.415 bid=312.39 ask=312.44 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-9994.379999999992 position=32 pnl=38.56000000000866 trading_pnl=42.955000000008184 trading_volume=1758 avg_size=6.790094224341463 avg_size_square=100.05140842464789
# 2023-05-17 17:00:00 99910
# mid_price=312.975 bid=312.95 ask=313.0 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=5.800000000012233 position=0 pnl=21.480000000012232 trading_pnl=28.845000000001953 trading_volume=1568 avg_size=5.886711116731285 avg_size_square=79.8121532917425
# 2023-05-17 17:30:00 101459
# mid_price=313.71000000000004 bid=313.68 ask=313.74 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=6291.969999999994 position=-20 pnl=35.309999999993344 trading_pnl=58.65499999999695 trading_volume=2174 avg_size=6.9344984167765755 avg_size_square=106.41875909147282
# 2023-05-17 18:00:00 96546
# mid_price=313.975 bid=313.95 ask=314.0 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-6892.969999999996 position=22 pnl=24.070000000004 trading_pnl=27.205000000007175 trading_volume=1322 avg_size=7.041621042004716 avg_size_square=102.33781619080933
# 2023-05-17 18:30:00 103007
# mid_price=313.83 bid=313.8 ask=313.86 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=5585.160000000025 position=-18 pnl=-34.35999999997446 trading_pnl=46.50500000000798 trading_volume=1772 avg_size=7.775422344587471 avg_size_square=145.1378126815008
# 2023-05-17 19:00:00 114316
# mid_price=313.24 bid=313.21 ask=313.27 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=900.5300000000134 position=-3 pnl=-15.57999999998652 trading_pnl=66.36499999999467 trading_volume=2499 avg_size=8.514713917939853 avg_size_square=167.47442576887582
# 2023-05-17 19:30:00 148469
# mid_price=313.695 bid=313.67 ask=313.72 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=608.1300000000119 position=-2 pnl=35.87000000001191 trading_pnl=162.86000000002596 trading_volume=5572 avg_size=7.437806073494229 avg_size_square=136.00753663150883
# *** Starting for ticker='MSFT' and date='20230518' ***
# 1690688
# 2023-05-18 14:00:00 200829
# mid_price=315.33500000000004 bid=315.31 ask=315.36 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# self.current_ts=Timestamp('2023-05-18 14:21:26.214978082')
# self.BID_SIM_ORDER_BOOK={0: (315.84, 40), 1: (315.83, 197), 2: (315.82, 297), 3: (315.81, 324), 4: (315.8, 408), 5: (315.79, 224), 6: (315.78, 399), 7: (315.77, 299), 8: (315.76, 350), 9: (315.75, 350)}
# self.ASK_SIM_ORDER_BOOK={0: (315.85, 32), 1: (315.86, 257), 2: (315.87, 320), 3: (315.88, 208), 4: (315.89, 282), 5: (315.9, 283), 6: (315.91, 282), 7: (315.92, 293), 8: (315.93, 101), 9: (315.94, 250)}
# self.BID_ALGO_ORDERS={315.8: 9}
# self.ASK_ALGO_ORDERS={315.87: 33}
# self.ALGO_POSITION=5
#
# mid_price=315.85 bid=315.82 ask=315.88 self.sigma_1min=0.0683 self.time_frac_elapsed=0.7146
# capital=-634.2899999999554 position=2 pnl=43.57000000004459 trading_pnl=100.60000000001307 trading_volume=4484 avg_size=7.1661196169393495 avg_size_square=130.19173247853726
# 2023-05-18 14:30:00 144219
# mid_price=316.245 bid=316.22 ask=316.27 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-1618.969999999972 position=5 pnl=-13.76999999997215 trading_pnl=47.375000000012655 trading_volume=2485 avg_size=6.104122794074709 avg_size_square=68.74125995051625
# 2023-05-18 15:00:00 140661
# mid_price=315.925 bid=315.9 ask=315.96 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=1562.3000000000147 position=-5 pnl=0.7300000000149147 trading_pnl=49.34500000000753 trading_volume=2513 avg_size=7.303972889630806 avg_size_square=129.3199085484932
# 2023-05-18 15:30:00 138380
# mid_price=317.395 bid=317.36 ask=317.42 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-3845.719999999972 position=12 pnl=-4.059999999971588 trading_pnl=115.69000000001836 trading_volume=3718 avg_size=6.418669400264071 avg_size_square=90.0719318517275
# 2023-05-18 16:00:00 150207
# mid_price=317.01 bid=316.98 ask=317.04 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# self.current_ts=Timestamp('2023-05-18 16:29:55.591873732')
# self.BID_SIM_ORDER_BOOK={0: (316.75, 188), 1: (316.74, 19), 2: (316.73, 94), 3: (316.72, 44), 4: (316.71, 262), 5: (316.7, 169), 6: (316.69, 207), 7: (316.68, 78), 8: (316.67, 194), 9: (316.66, 200)}
# self.ASK_SIM_ORDER_BOOK={0: (316.78, 8), 1: (316.79, 192), 2: (316.8, 95), 3: (316.81, 175), 4: (316.82, 100), 5: (316.83, 350), 6: (316.84, 100), 7: (316.85, 150), 8: (316.86, 100), 9: (316.87, 179)}
# self.BID_ALGO_ORDERS={316.75: 8}
# self.ASK_ALGO_ORDERS={316.8: 18}
# self.ALGO_POSITION=-18
#
# mid_price=316.765 bid=316.74 ask=316.8 self.sigma_1min=0.0554 self.time_frac_elapsed=0.9976
# capital=2766.7899999999863 position=-9 pnl=-38.85000000001384 trading_pnl=137.79000000000622 trading_volume=4493 avg_size=6.811230026688567 avg_size_square=95.29708127476054
# 2023-05-18 16:30:00 123741
# mid_price=316.745 bid=316.72 ask=316.77 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=5700.480000000025 position=-18 pnl=35.7200000000247 trading_pnl=83.66000000000815 trading_volume=2738 avg_size=5.191803301782233 avg_size_square=50.94307548369116
# 2023-05-18 17:00:00 113378
# mid_price=316.225 bid=316.2 ask=316.26 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-27217.019999999997 position=86 pnl=49.82000000000044 trading_pnl=156.14500000000544 trading_volume=3580 avg_size=7.539676357698771 avg_size_square=106.22725877560606
# 2023-05-18 17:30:00 109496
# mid_price=316.58500000000004 bid=316.56 ask=316.62 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=1916.1600000000162 position=-6 pnl=35.120000000016226 trading_pnl=37.03000000000397 trading_volume=1646 avg_size=5.535502977846393 avg_size_square=68.62890576759736
# 2023-05-18 18:00:00 108678
# mid_price=316.27 bid=316.24 ask=316.3 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-18406.419999999984 position=58 pnl=-15.059999999982683 trading_pnl=25.659999999998586 trading_volume=1348 avg_size=8.312129603155807 avg_size_square=122.82263802679181
# 2023-05-18 18:30:00 114850
# mid_price=316.82 bid=316.79 ask=316.85 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=317.74000000001837 position=-1 pnl=14.150000000018359 trading_pnl=26.04000000000658 trading_volume=1371 avg_size=6.132169088227422 avg_size_square=67.46532871098364
# 2023-05-18 19:00:00 131420
# mid_price=317.3 bid=317.27 ask=317.33 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=8595.150000000025 position=-27 pnl=44.27000000002496 trading_pnl=57.37500000001349 trading_volume=2621 avg_size=8.325799702689714 avg_size_square=146.43704796539842
# 2023-05-18 19:30:00 214829
# mid_price=317.815 bid=317.79 ask=317.84 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# self.current_ts=Timestamp('2023-05-18 19:54:02.834458689')
# self.BID_SIM_ORDER_BOOK={0: (318.77, 218), 1: (318.76, 34), 2: (318.75, 187), 3: (318.74, 50), 4: (318.73, 456), 5: (318.72, 250), 6: (318.71, 100), 7: (318.7, 282), 8: (318.69, 504), 9: (318.68, 150)}
# self.ASK_SIM_ORDER_BOOK={0: (318.82, 517), 1: (318.83, 189), 2: (318.84, 365), 3: (318.85, 428), 4: (318.86, 331), 5: (318.87, 326), 6: (318.88, 227), 7: (318.89, 105), 8: (318.9, 50), 9: (318.91, 25)}
# self.BID_ALGO_ORDERS={318.76: 7}
# self.ASK_ALGO_ORDERS={318.83: 14}
# self.ALGO_POSITION=2
#
# mid_price=318.79499999999996 bid=318.76 ask=318.82 self.sigma_1min=0.0362 self.time_frac_elapsed=0.8016
# capital=-576.7199999999548 position=2 pnl=132.36000000004523 trading_pnl=168.85500000001744 trading_volume=7196 avg_size=7.597822979994394 avg_size_square=136.98391313988247
# *** Starting for ticker='MSFT' and date='20230519' ***
# 1861590
# 2023-05-19 14:00:00 203779
# mid_price=317.74 bid=317.71 ask=317.77 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# self.current_ts=Timestamp('2023-05-19 14:19:50.166434154')
# self.BID_SIM_ORDER_BOOK={0: (317.62, 17), 1: (317.61, 134), 2: (317.6, 86), 3: (317.59, 359), 4: (317.58, 209), 5: (317.57, 146), 6: (317.56, 134), 7: (317.55, 142), 8: (317.54, 137), 9: (317.53, 337)}
# self.ASK_SIM_ORDER_BOOK={0: (317.64, 217), 1: (317.65, 68), 2: (317.66, 267), 3: (317.67, 217), 4: (317.68, 292), 5: (317.69, 66), 6: (317.7, 159), 7: (317.71, 209), 8: (317.72, 359), 9: (317.73, 309)}
# self.BID_ALGO_ORDERS={317.6: 18}
# self.ASK_ALGO_ORDERS={317.65: 26}
# self.ALGO_POSITION=7
#
# mid_price=317.63 bid=317.6 ask=317.66 self.sigma_1min=0.0735 self.time_frac_elapsed=0.6612
# capital=-1589.1399999999667 position=5 pnl=24.460000000033325 trading_pnl=49.64000000001236 trading_volume=2485 avg_size=5.961850318695709 avg_size_square=91.77391466728571
# 2023-05-19 14:30:00 165333
# mid_price=317.82 bid=317.79 ask=317.85 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# self.current_ts=Timestamp('2023-05-19 14:56:28.691746857')
# self.BID_SIM_ORDER_BOOK={0: (317.83, 10), 1: (317.82, 72), 2: (317.81, 299), 3: (317.8, 164), 4: (317.79, 227), 5: (317.78, 312), 6: (317.77, 235), 7: (317.76, 290), 8: (317.75, 200), 9: (317.74, 125)}
# self.ASK_SIM_ORDER_BOOK={0: (317.85, 133), 1: (317.86, 46), 2: (317.87, 114), 3: (317.88, 177), 4: (317.89, 290), 5: (317.9, 165), 6: (317.91, 290), 7: (317.92, 240), 8: (317.93, 150), 9: (317.94, 173)}
# self.BID_ALGO_ORDERS={317.81: 22}
# self.ASK_ALGO_ORDERS={317.86: 9}
# self.ALGO_POSITION=-16
#
# mid_price=317.84000000000003 bid=317.81 ask=317.87 self.sigma_1min=0.0528 self.time_frac_elapsed=0.8826
# capital=17117.75000000002 position=-54 pnl=-20.469999999982537 trading_pnl=50.72000000001246 trading_volume=2298 avg_size=8.046803797208412 avg_size_square=118.55488450255015
# 2023-05-19 15:00:00 274266
# mid_price=317.86 bid=317.83 ask=317.89 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# self.current_ts=Timestamp('2023-05-19 15:17:27.374898669')
# self.BID_SIM_ORDER_BOOK={0: (317.77, 27), 1: (317.75, 278), 2: (317.74, 33), 3: (317.73, 263), 4: (317.72, 100), 5: (317.71, 1058), 6: (317.7, 1083), 7: (317.69, 358), 8: (317.68, 108), 9: (317.67, 250)}
# self.ASK_SIM_ORDER_BOOK={0: (317.79, 70), 1: (317.8, 188), 2: (317.81, 150), 3: (317.82, 150), 4: (317.83, 250), 5: (317.84, 150), 6: (317.85, 125), 7: (317.86, 150), 8: (317.87, 100), 9: (317.88, 150)}
# self.BID_ALGO_ORDERS={317.75: 20}
# self.ASK_ALGO_ORDERS={317.8: 5}
# self.ALGO_POSITION=-11
#
# mid_price=317.78 bid=317.75 ask=317.81 self.sigma_1min=0.1180 self.time_frac_elapsed=0.5819
# capital=984.1600000000362 position=-3 pnl=63.97000000003627 trading_pnl=74.65500000001484 trading_volume=3135 avg_size=5.785883445815641 avg_size_square=74.26930543848648
# 2023-05-19 15:30:00 225088
# mid_price=317.12 bid=317.09 ask=317.15 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# self.current_ts=Timestamp('2023-05-19 15:46:43.604682445')
# self.BID_SIM_ORDER_BOOK={0: (317.67, 100), 1: (317.66, 39), 2: (317.65, 219), 3: (317.64, 349), 4: (317.63, 460), 5: (317.62, 210), 6: (317.61, 270), 7: (317.6, 120), 8: (317.59, 285), 9: (317.58, 750)}
# self.ASK_SIM_ORDER_BOOK={0: (317.69, 24), 1: (317.7, 72), 2: (317.71, 288), 3: (317.72, 288), 4: (317.73, 314), 5: (317.74, 163), 6: (317.75, 514), 7: (317.76, 50), 8: (317.77, 250), 9: (317.78, 161)}
# self.BID_ALGO_ORDERS={317.64: 26}
# self.ASK_ALGO_ORDERS={317.7: 2}
# self.ALGO_POSITION=-6
#
# mid_price=317.68 bid=317.65 ask=317.71 self.sigma_1min=0.0852 self.time_frac_elapsed=0.5576
# capital=4116.290000000015 position=-13 pnl=38.98000000001499 trading_pnl=208.83000000000638 trading_volume=5071 avg_size=7.003281751961507 avg_size_square=97.943043440781
# 2023-05-19 16:00:00 138293
# mid_price=317.53999999999996 bid=317.51 ask=317.57 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-966.9399999999923 position=3 pnl=11.77000000000756 trading_pnl=83.70000000001217 trading_volume=2783 avg_size=6.510796197736929 avg_size_square=92.84646077808371
# 2023-05-19 16:30:00 125192
# mid_price=316.935 bid=316.91 ask=316.96 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=1921.7600000000311 position=-6 pnl=34.38000000003116 trading_pnl=44.290000000006174 trading_volume=1714 avg_size=6.303911805366738 avg_size_square=89.57632842503448
# 2023-05-19 17:00:00 97638
# mid_price=317.44 bid=317.41 ask=317.47 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-9545.319999999998 position=30 pnl=10.220000000001383 trading_pnl=43.33999999999758 trading_volume=1374 avg_size=9.042410277813426 avg_size_square=144.52184131569908
# 2023-05-19 17:30:00 103355
# mid_price=318.075 bid=318.04 ask=318.1 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-7912.6299999999865 position=25 pnl=42.320000000013536 trading_pnl=44.14500000000443 trading_volume=1745 avg_size=10.000786396082077 avg_size_square=195.22592045669205
# 2023-05-19 18:00:00 122096
# mid_price=317.47 bid=317.44 ask=317.5 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-1636.7399999999689 position=5 pnl=-26.989999999968767 trading_pnl=48.08500000001349 trading_volume=1985 avg_size=7.545682826670838 avg_size_square=127.65651687178405
# 2023-05-19 18:30:00 124124
# mid_price=317.985 bid=317.96 ask=318.02 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-3495.4199999999855 position=11 pnl=13.760000000014662 trading_pnl=18.974999999999802 trading_volume=1063 avg_size=6.180239223978804 avg_size_square=93.86484776631416
# 2023-05-19 19:00:00 119654
# mid_price=318.005 bid=317.98 ask=318.03 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# capital=-2224.289999999977 position=7 pnl=14.910000000022556 trading_pnl=21.975000000007263 trading_volume=1271 avg_size=7.026636937806402 avg_size_square=106.71979723051925
# 2023-05-19 19:30:00 162772
# mid_price=318.07 bid=318.04 ask=318.1 self.sigma_1min=nan self.time_frac_elapsed=0.0000
# self.current_ts=Timestamp('2023-05-19 19:59:00.000503922')
# self.BID_SIM_ORDER_BOOK={0: (318.65, 299), 1: (318.64, 275), 2: (318.63, 50), 3: (318.62, 150), 4: (318.61, 251), 5: (318.6, 150), 6: (318.59, 100), 7: (318.58, 150), 8: (318.57, 481), 9: (318.56, 250)}
# self.ASK_SIM_ORDER_BOOK={0: (318.66, 524), 1: (318.67, 109), 2: (318.68, 336), 3: (318.69, 254), 4: (318.7, 506), 5: (318.71, 352), 6: (318.72, 525), 7: (318.73, 418), 8: (318.74, 708), 9: (318.75, 776)}
# self.BID_ALGO_ORDERS={318.64: 100}
# self.ASK_ALGO_ORDERS={318.7: 40}
# self.ALGO_POSITION=-15
#
# mid_price=318.655 bid=318.63 ask=318.69 self.sigma_1min=0.0305 self.time_frac_elapsed=0.9667
# capital=24206.720000000023 position=-76 pnl=45.34000000002197 trading_pnl=82.01499999999896 trading_volume=3550 avg_size=6.723925998782447 avg_size_square=82.36371972165794

# %%
model_name = 'ho_and_stoll'

out_df = pd.DataFrame(output).T
del out_df['trades']
del out_df['quotes']

out_df['utility'] = 100 * (out_df['net_pnl'] + 2 * out_df['trading_pnl'] - 0.01 * out_df['avg_size_square']) / out_df['trading_volume']

print(out_df.mean())
print(out_df.std())

out_df.to_csv(f'backtest_output_{model_name}.csv')
out_df

trades_df = pd.concat([o['trades'] for o in output.values()])
trades_df.to_csv(f'backtest_output_{model_name}_trades.csv')

quotes_df = pd.concat([o['quotes'] for o in output.values()])
quotes_df.to_csv(f'backtest_output_{model_name}_quotes.csv')
# Out:
# eod_position              4.45
# eod_cash          -1389.260333
# net_pnl                17.1125
# trading_pnl           56.76625
# avg_size              7.107574
# avg_size_square     121.646773
# trading_volume     2265.883333
# volatility            0.045957
# net_return              -0.105
# utility               5.469845
# dtype: object
# eod_position          35.280198
# eod_cash           11033.035288
# net_pnl                28.97548
# trading_pnl           42.013307
# avg_size               1.522605
# avg_size_square        54.78434
# trading_volume      1308.447289
# volatility             0.012127
# net_return             0.564748
# utility                1.712752
# dtype: object
